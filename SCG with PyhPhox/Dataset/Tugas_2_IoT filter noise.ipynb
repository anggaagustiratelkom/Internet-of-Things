# %%
import plotly as py
import numpy as np 
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objs as go
import plotly.figure_factory as ff
import scipy
from scipy import signal

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !ls "drive/My Drive/Tugas_IoT/data1.xlsx"
# !ls "drive/My Drive/Tugas_IoT/data2.xlsx"
# !ls "drive/My Drive/Tugas_IoT/data3.xlsx"
# !ls "drive/My Drive/Tugas_IoT/data4.xlsx"
# !ls "drive/My Drive/Tugas_IoT/data5.xlsx"
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 76
# 'drive/My Drive/Tugas_IoT/data1.xlsx'
# 'drive/My Drive/Tugas_IoT/data2.xlsx'
# 'drive/My Drive/Tugas_IoT/data3.xlsx'
# 'drive/My Drive/Tugas_IoT/data4.xlsx'
# 'drive/My Drive/Tugas_IoT/data5.xlsx'

# %%
#Perhitungan Low Pass Filter
fc = 0.1
b = 0.08
N = int(np.ceil((4 / b)))
if not N % 2: N += 1
n = np.arange(N)

sinc_func = np.sinc(2 * fc * (n - (N - 1) / 2.))
window = 0.42 - 0.5 * np.cos(2 * np.pi * n / (N - 1)) + 0.08 * np.cos(4 * np.pi * n / (N - 1))
sinc_func = sinc_func * window
sinc_func = sinc_func / np.sum(sinc_func)

# %%
waktu1 = df1["Time (s)"]
accelx1 = df1["Acceleration x (m/s^2)"]
plt.plot(waktu1,accelx1)

# %%
waktu2 = df2["Time (s)"]
accelx2 = df2["Acceleration x (m/s^2)"]
plt.plot(waktu2,accelx2)

# %%
waktu3 = df3["Time (s)"]
accelx3 = df3["Acceleration x (m/s^2)"]
plt.plot(waktu3,accelx3)

# %%
waktu4 = df4["Time (s)"]
accelx4 = df4["Acceleration x (m/s^2)"]
plt.plot(waktu4,accelx4)

# %%
waktu5 = df5["Time (s)"]
accelx5 = df5["Acceleration x (m/s^2)"]
plt.plot(waktu5,accelx5)

# %%
s = list(map(float,df1["Acceleration x (m/s^2)"]))
nonoise1 = np.convolve(s, sinc_func)
plt.plot(list(range(len(nonoise1))),nonoise1)

# %%
s = list(map(float,df2["Acceleration x (m/s^2)"]))
nonoise2 = np.convolve(s, sinc_func)
plt.plot(list(range(len(nonoise2))),nonoise2)

# %%
s = list(map(float,df3["Acceleration x (m/s^2)"]))
nonoise3 = np.convolve(s, sinc_func)
plt.plot(list(range(len(nonoise3))),nonoise3)

# %%
s = list(map(float,df4["Acceleration x (m/s^2)"]))
nonoise4 = np.convolve(s, sinc_func)
plt.plot(list(range(len(nonoise4))),nonoise4)

# %%
s = list(map(float,df5["Acceleration x (m/s^2)"]))
nonoise5 = np.convolve(s, sinc_func)
plt.plot(list(range(len(nonoise5))),nonoise5)
